# %%
import sqlite3

# %%
conn    = sqlite3.connect("tasky.db")
print("Opened database successfully")
curA        = conn.cursor()
# Out:
# Opened database successfully

# %%
conn.execute('''CREATE TABLE blearn (learn_id int AUTO_INCREMENT PRIMARY KEY,learn_date date, learn_start_time datetime,learn_end_time datetime,area_of_study VARCHAR(255),sub_area VARCHAR(255),completion_status VARCHAR(255),learning_src TEXT,brief_desc TEXT,comments TEXT,code_practice_link TEXT,audit_ts DATETIME DEFAULT (STRFTIME('%d-%m-%Y   %H:%M', 'NOW','localtime')))''')
print("Table created successfully")
#conn.close()
# Out:
# Table created successfully

# %%
#show tables
tables =curA.execute("select name from sqlite_master where type = 'table'")
for t in tables:
    print(t)
# Out:
# ('alembic_version',)
# ('blearn',)

# %%
tasky = curA.execute("select * from blearn order by learn_id desc")
for t in tasky:
    print(t)
# Out:
# (4, '2020-08-04', '2020-08-04 07:00:00', '2020-08-04 08:00:00', 'Python', 'Python - Basics', 'WIP', 'Datacamp', 'For Machine Learning', 'For Machine Learning', 'Datacamp', '2020-08-05 10:18:53')
# (3, '2020-08-03', '2020-08-03 10:00:00', '2020-08-03 12:00:00', 'Python', 'Flask Programming', 'Completed', 'Self', 'Added basic Login page to the existing app but other endpoints not protected', 'need to protect other endpoints', 'Pycharm + GCP ,will be pushed to Github', '2020-08-05 10:18:53')
# (2, '2020-08-02', '2020-08-02 10:00:00', '2020-08-02 12:00:00', 'Python', 'Flask Programming', 'Completed', 'Self', 'Create DB in AWS,Flask running in GCP,small learning tracker app', 'Create DB in AWS,Flask running in GCP,small learning tracker app', 'Pycharm + GCP ,will be pushed to Github', '2020-08-05 10:18:53')
# (1, '2020-08-01', '2020-08-01 10:00:00', '2020-08-01 15:00:00', 'Python', 'Flask Programming - Basics', 'Completed', 'Youtube - Parwaiz Channel', 'Create DB in AWS,Flask running in local,small learning tracker app', 'Create DB in AWS,Flask running in local,small learning tracker app', 'Pycharm,will be pushed to Github', '2020-08-05 10:18:53')
